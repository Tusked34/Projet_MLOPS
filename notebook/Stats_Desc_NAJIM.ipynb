# %%
import sys
import os
# Ajouter le chemin du dossier parent à sys.path
notebook_dir = os.path.abspath('..')  # Dossier parent de "notebook/"
sys.path.append(notebook_dir)

# Importer toutes les fonctions du module
from fonctions.fct_importation import *
# Out:
# c:\Users\najim\Documents\Master 2\MLOps\projet\fonctions\importation.py:27: SyntaxWarning: invalid escape sequence '\*'
#   for fichier in glob.glob(f"{path_folder_files}\*.csv"):

# %%
df = etl(r'C:\Users\najim\Documents\Master 2\MLOps\projet\data')
df
# Out:
# **************************************************
# Démarrage du processus d'importation
#
# Importation du fichier HousePrice_Bronx_County.csv
# Importation du fichier HousePrice_Brooklyn.csv
# Importation du fichier HousePrice_Brooklyn_Heights.csv
# Importation du fichier HousePrice_Coney_Island.csv
# Importation du fichier HousePrice_Dumbo.csv
# Importation du fichier HousePrice_East_Bronx.csv
# Importation du fichier HousePrice_Flushing.csv
# Importation du fichier HousePrice_Fort_Hamilton.csv
# Importation du fichier HousePrice_Jackson_Heights.csv
# Importation du fichier HousePrice_Kings_County.csv
# Importation du fichier HousePrice_Manhattan.csv
# Importation du fichier HousePrice_New_York.csv
# Importation du fichier HousePrice_New_York_County.csv
# Importation du fichier HousePrice_Queens.csv
# Importation du fichier HousePrice_Queens_County.csv
# Importation du fichier HousePrice_Rego_Park.csv
# Importation du fichier HousePrice_Richmond_County.csv
# Importation du fichier HousePrice_Riverdale.csv
# Importation du fichier HousePrice_Snyder_Avenue.csv
# Importation du fichier HousePrice_Staten_Island.csv
# Importation du fichier HousePrice_The_Bronx.csv
# Processus d'importation terminé
# **************************************************
# Dimension du dataset : 4801 lignes et 17 colonnes
#                                             BROKERTITLE  \
# 0                 Brokered by Keller Williams Ny Realty
# 1                                              NoBroker
# 2                                Brokered by Exp Realty
# 3            Brokered by Meyers Enterprise Realty Group
# 4                  Brokered by Prospes Real Estate Corp
# ...                                                 ...
# 4796             Brokered by Corcoran Westside Columbus
# 4797                                Brokered by COMPASS
# 4798                        Brokered by Mp Power Realty
# 4799                   Brokered by Brown Harris Stevens
# 4800  Brokered by OneKey MLS LLC - Foxworth Realty, ...
#
#                             TYPE    PRICE  BEDS      BATH  PROPERTYSQFT  \
# 0     Multi-family home for sale  1100000     6  3.000000   2837.000000
# 1     Multi-family home for sale   925000     5  2.000000   2750.000000
# 2     Multi-family home for sale   700000     6  2.000000   3053.000000
# 3                  Land for sale   119000     3  2.373861   2184.207862
# 4     Multi-family home for sale   600000     2  2.000000   2184.207862
# ...                          ...      ...   ...       ...           ...
# 4796              Co-op for sale   280000     2  1.000000   1050.000000
# 4797              Co-op for sale   375000     2  1.000000   2184.207862
# 4798              Co-op for sale   167999     1  1.000000   2184.207862
# 4799              Co-op for sale   309000     2  1.000000   2184.207862
# 4800              Co-op for sale   295500     1  1.000000   2184.207862
#
#                              ADDRESS               STATE  \
# 0     1038 Throggs Neck Expy Unit Sr     Bronx, NY 10465
# 1                  543 Hollywood Ave     Bronx, NY 10465
# 2           229 W Tremont Ave Unit A     Bronx, NY 10453
# 3                 3652 DE Reimer Ave     Bronx, NY 10466
# 4                1406 Mac Donough Pl     Bronx, NY 10465
# ...                              ...                 ...
# 4796       3000 Valentine Ave Apt 3B     Bronx, NY 10458
# 4797      5900 Arlington Ave Apt 10H     Bronx, NY 10471
# 4798       3121 Middletown Rd Apt 6B     Bronx, NY 10461
# 4799      3935 Blackstone Ave Apt 3F     Bronx, NY 10471
# 4800       3015 Riverdale Ave Apt 2A  New York, NY 10463
#
#                                        MAIN_ADDRESS  \
# 0     1038 Throggs Neck Expy Unit SrBronx, NY 10465
# 1                  543 Hollywood AveBronx, NY 10465
# 2           229 W Tremont Ave Unit ABronx, NY 10453
# 3                 3652 DE Reimer AveBronx, NY 10466
# 4                1406 Mac Donough PlBronx, NY 10465
# ...                                             ...
# 4796       3000 Valentine Ave Apt 3BBronx, NY 10458
# 4797      5900 Arlington Ave Apt 10HBronx, NY 10471
# 4798       3121 Middletown Rd Apt 6BBronx, NY 10461
# 4799      3935 Blackstone Ave Apt 3FBronx, NY 10471
# 4800    3015 Riverdale Ave Apt 2ANew York, NY 10463
#
#      ADMINISTRATIVE_AREA_LEVEL_2      LOCALITY   SUBLOCALITY      STREET_NAME  \
# 0                  United States      New York  Bronx County        The Bronx
# 1                  United States      New York  Bronx County        The Bronx
# 2                  United States      New York  Bronx County        The Bronx
# 3                  United States      New York  Bronx County        The Bronx
# 4                  United States      New York  Bronx County        The Bronx
# ...                          ...           ...           ...              ...
# 4796                    New York  Bronx County     The Bronx       West Bronx
# 4797                    New York  Bronx County     The Bronx  North Riverdale
# 4798                    New York  Bronx County     The Bronx       Pelham Bay
# 4799                    New York  Bronx County     The Bronx        Riverdale
# 4800                    New York  Bronx County     The Bronx   Spuyten Duyvil
#
#                    LONG_NAME                              FORMATTED_ADDRESS  \
# 0     Throgs Neck Expressway    1038 Throgs Neck Expy, Bronx, NY 10465, USA
# 1           Hollywood Avenue        543 Hollywood Ave, Bronx, NY 10465, USA
# 2        West Tremont Avenue        229 W Tremont Ave, Bronx, NY 10453, USA
# 3           De Reimer Avenue       3652 De Reimer Ave, Bronx, NY 10466, USA
# 4          Mac Donough Place      1406 Mac Donough Pl, Bronx, NY 10465, USA
# ...                      ...                                            ...
# 4796                    3000   3000 Valentine Ave #3b, Bronx, NY 10458, USA
# 4797                    5900  5900 Arlington Ave #10h, Bronx, NY 10471, USA
# 4798                    3121   3121 Middletown Rd #6b, Bronx, NY 10461, USA
# 4799                    3935  3935 Blackstone Ave #3f, Bronx, NY 10471, USA
# 4800                    3015   3015 Riverdale Ave #2a, Bronx, NY 10463, USA
#
#        LATITUDE  LONGITUDE
# 0     40.834394 -73.822110
# 1     40.824239 -73.817381
# 2     40.852813 -73.917687
# 3     40.884170 -73.838839
# 4     40.842954 -73.824959
# ...         ...        ...
# 4796  40.872414 -73.885223
# 4797  40.909252 -73.905421
# 4798  40.845596 -73.826422
# 4799  40.890384 -73.911788
# 4800  40.880930 -73.910749
#
# [4801 rows x 17 columns]
